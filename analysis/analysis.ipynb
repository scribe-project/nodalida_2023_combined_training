# %% [markdown]
# # Code for the analyses in the paper "Improving Generalization of Norwegian ASR with Limited Linguistic Resources"

# %% [markdown]
# ## Imports and loading of datasets

# %%
# Imports
import pandas as pd
from jiwer import wer, cer
from scipy.stats import power_divergence
from collections import Counter
from pathlib import Path
import re
import numpy as np

# %%
# Make a df of the transcriptions
w_lm = False
filenamepattern = re.compile(r"^((?:nbtale12|nbtale3|npsc|nst|rundkast)(?:_(?:test|validation))*)_*(.*)")
if w_lm:
    filenamepattern = re.compile(r"^((?:nbtale12|nbtale3|npsc|nst|rundkast)(?:_(?:test|validation))*)_*(.*)_w_lm")
dfs = {}
csvs = Path("transcriptions").glob("*.csv")
if w_lm:
    csvs = Path("transcriptions_w_lm").glob("*.csv")

for fn in csvs:
    match = filenamepattern.match(fn.stem)
    dataset = match.group(1)
    asr_model = match.group(2)
    df = pd.read_csv(fn)
    if dataset not in dfs.keys():
        df["dataset"] = dataset
        df[asr_model] = df["transcription"]
        df.drop("transcription", axis=1, inplace=True)
        dfs[dataset] = df
    else:
        dfs[dataset][asr_model] = df["transcription"]
df = pd.concat(dfs.values())

def clean_mult_space(trans):
    """Clean up instances of multiple spaces"""
    if isinstance(trans, str):
        trans = trans.strip()
        trans = re.sub(r"\s\s+", " ", trans)
        trans = trans.replace("\\", " ")
    return trans

# This does not appear to have any effect on WER. However, it removes empty strings
# from lexical analysis   
df["standardized_text"] = df["standardized_text"].apply(lambda x: clean_mult_space(x))
df["stortinget_model"] = df["stortinget_model"].apply(lambda x: clean_mult_space(x))
df["combined_short_model"] = df["combined_short_model"].apply(lambda x: clean_mult_space(x))
df["combined_long_model"] = df["combined_long_model"].apply(lambda x: clean_mult_space(x))
df["rundkast_model"] = df["rundkast_model"].apply(lambda x: clean_mult_space(x))

# %%
df.dataset.unique()
# Out:
# array(['rundkast_test', 'npsc_test', 'nbtale12', 'rundkast_validation',
#        'npsc_validation', 'nst_validation', 'nst_test', 'nbtale3'],
#       dtype=object)

# %%
df = df.query("dataset not in ['npsc_validation', 'rundkast_validation', 'nst_validation']")

# %%
df = df.drop('Unnamed: 0', axis=1).dropna(subset=["standardized_text"]).query("region != 'unknown'")

# %%
round(df.groupby("dataset").duration.sum()/3600, 1)
# Out:
# dataset
# nbtale12         15.6
# nbtale3          11.6
# npsc_test         9.1
# nst_test         25.6
# rundkast_test     5.8
# Name: duration, dtype: float64

# %%
# Doing replacements in a separate df so we can see how much
# these transcription differences contribute to the results

replacements = {
    r"(\b)n r k s(\b)": r"\1nrks\2",
    r"(\b)n r k(\b)": r"\1nrk\2",
    r"(\b)u s a s(\b)": r"\1usas\2",
    r"(\b)u s a(\b)": r"\1usa\2",
    r"(\b)a f p(\b)": r"\1afp\2",
    r"(\b)u d i s(\b)": r"\1udis\2",
    r"(\b)u d i(\b)": r"\1udi\2",
    r"(\b)e u s(\b)": r"\1eus\2",
    r"(\b)e u(\b)": r"\1eu\2",
    r"(\b)s a s(\b)": r"\1sas\2",
    r"(\b)s m s(\b)": r"\1sms\2",
    r"(\b)n t n u(\b)": r"\1ntnu\2",
    r"(\b)d n b s(\b)": r"\1dnbs\2",
    r"(\b)d n b(\b)": r"\1dnb\2",
    r"(\b)o s s e s(\b)": r"\1osses\2",
    r"(\b)o s s e(\b)": r"\1osse\2",
    r"(\b)s v s(\b)": r"\1svs\2",
    r"(\b)s v(\b)": r"\1sv\2",
    r"-": "",
    r"(\b)mmm(\b)": r"\1\2",
    r"(\b)eee(\b)": r"\1\2",
    r"(\b)qqq(\b)": r"\1\2",
}
def clean_string(string):
    if type(string) == str:
        for k, v in replacements.items():
            string = re.sub(k, v, string)
        if string == " ":
            string = ""
    return string

df_cleaned = df.copy()
df_cleaned["standardized_text"] = df_cleaned["standardized_text"].apply(lambda x: clean_string(x))
df_cleaned["stortinget_model"] = df_cleaned["stortinget_model"].apply(lambda x:clean_string(x))
df_cleaned["combined_short_model"] = df_cleaned["combined_short_model"].apply(lambda x: clean_string(x))
df_cleaned["combined_long_model"] = df_cleaned["combined_long_model"].apply(lambda x: clean_string(x))
df_cleaned["rundkast_model"] = df_cleaned["rundkast_model"].apply(lambda x: clean_string(x))
df_cleaned = df_cleaned[~df_cleaned.standardized_text.isin([' ', ''])]

# %%
df["word_count"] = df.standardized_text.apply(lambda x: len(x.split(" ")))
df_cleaned["word_count"] = df_cleaned.standardized_text.apply(lambda x: len(x.split(" ")))

# %%
def compute_score(gold, pred, method=wer):
    """Score a segment according to a scoring method
    (wer or cer)."""
    try:
        if type(pred) != str:
            pred = ""
        if type(gold) != str:
            gold = ""
        return method(gold, pred)*100
    except ValueError:
        return 100

# %%
# Get number of word and character errors per segments
# This makes it easier to calculate WER and CER independent
# of segment length later
df["rundkast_num_word_errors"] = df.apply(lambda row: compute_score(row["standardized_text"], row["rundkast_model"])*row["word_count"], axis=1)
df["stortinget_num_word_errors"] = df.apply(lambda row: compute_score(row["standardized_text"], row["stortinget_model"])*row["word_count"], axis=1)
df["combined_short_num_word_errors"] = df.apply(lambda row: compute_score(row["standardized_text"], row["combined_short_model"])*row["word_count"], axis=1)
df["combined_long_num_word_errors"] = df.apply(lambda row: compute_score(row["standardized_text"], row["combined_long_model"])*row["word_count"], axis=1)
df_native = df.query("region != 'foreign'")
df_foreign = df.query("region == 'foreign'")

df_cleaned["rundkast_num_word_errors"] = df_cleaned.apply(lambda row: compute_score(row["standardized_text"], row["rundkast_model"])*row["word_count"], axis=1)
df_cleaned["stortinget_num_word_errors"] = df_cleaned.apply(lambda row: compute_score(row["standardized_text"], row["stortinget_model"])*row["word_count"], axis=1)
df_cleaned["combined_short_num_word_errors"] = df_cleaned.apply(lambda row: compute_score(row["standardized_text"], row["combined_short_model"])*row["word_count"], axis=1)
df_cleaned["combined_long_num_word_errors"] = df_cleaned.apply(lambda row: compute_score(row["standardized_text"], row["combined_long_model"])*row["word_count"], axis=1)
df_cleaned_native = df_cleaned.query("region != 'foreign'")
df_cleaned_foreign = df_cleaned.query("region == 'foreign'")

# %% [markdown]
# ## Calculation functions

# %%
def get_wer(df, num_error_col):
    return round(df[num_error_col].sum()/df["word_count"].sum(), 1)

# %%
def relative_change(initial_val, final_val):
    return round((final_val-initial_val)/initial_val*100, 1)

# %%
def get_score_by_column(df, gb_col, stat_col, count_col):
    """group by gb_col in ds and calculate error rate given a stat_col with segmentwise number of errors"""
    return round(df.groupby(gb_col)[stat_col].sum()/df.groupby(gb_col)[count_col].sum(), 1)

# %%
def make_grouped_df(df, gb_col):
    """Pass a groubby column and create a df with scoring and relative change for different datasets
    and dataset combinations"""
    grouped_df = pd.DataFrame(get_score_by_column(df, gb_col, "rundkast_num_word_errors", "word_count"))
    grouped_df.columns = ["rundkast_wer"]
    grouped_df["stortinget_wer"] = get_score_by_column(df, gb_col, "stortinget_num_word_errors", "word_count")
    grouped_df["combined_short_wer"] = get_score_by_column(df, gb_col, "combined_short_num_word_errors", "word_count")
    grouped_df["combined_long_wer"] = get_score_by_column(df, gb_col, "combined_long_num_word_errors", "word_count")
    grouped_df["relative_change_rundkast_to_combined_short_wer"] = grouped_df.apply(lambda row: relative_change(row.rundkast_wer, row.combined_short_wer), axis=1)
    grouped_df["relative_change_stortinget_to_combined_short_wer"] = grouped_df.apply(lambda row: relative_change(row.stortinget_wer, row.combined_short_wer), axis=1)
    grouped_df["relative_change_rundkast_to_combined_long_wer"] = grouped_df.apply(lambda row: relative_change(row.rundkast_wer, row.combined_long_wer), axis=1)
    grouped_df["relative_change_stortinget_to_combined_long_wer"] = grouped_df.apply(lambda row: relative_change(row.stortinget_wer, row.combined_long_wer), axis=1)
    grouped_df["relative_change_combined_short_to_combined_long_wer"] = grouped_df.apply(lambda row: relative_change(row.combined_short_wer, row.combined_long_wer), axis=1)

    return grouped_df

# %%
def make_grouped_wer_plot(results_df, x_label):
    dataset_plot = results_df[["rundkast_wer", "stortinget_wer", "combined_short_wer", "combined_long_wer"]].plot(kind='bar', figsize=(10,10))
    dataset_plot.set_xlabel(x_label)
    dataset_plot.set_ylabel("wer")

# %% [markdown]
# ## Scoring on the corpus as a whole

# %%
def get_corpus_stats(df):
    return {
    "wer_rundkast": get_wer(df, "rundkast_num_word_errors"),
    "wer_stortinget" : get_wer(df, "stortinget_num_word_errors"),
    "wer_combined_short": get_wer(df, "combined_short_num_word_errors"),
    "wer_combined_long": get_wer(df, "combined_long_num_word_errors"),
    }

def print_corpus_stats(stats_dict):
    print(f"WER Rundkast: {stats_dict['wer_rundkast']}")
    print(f"WER Stortinget: {stats_dict['wer_stortinget']}")
    print(f"WER combined_short: {stats_dict['wer_combined_short']}")
    print(f"WER combined_long: {stats_dict['wer_combined_long']}")
    print(f"Relative WER change from Rundkast to combined_short: {relative_change(stats_dict['wer_rundkast'], stats_dict['wer_combined_short'])}")
    print(f"Relative WER change from Rundkast to combined_long: {relative_change(stats_dict['wer_rundkast'], stats_dict['wer_combined_long'])}")
    print(f"Relative WER change from Stortinget to combined_short: {relative_change(stats_dict['wer_stortinget'], stats_dict['wer_combined_short'])}")
    print(f"Relative WER change from Stortinget to combined_long: {relative_change(stats_dict['wer_stortinget'], stats_dict['wer_combined_long'])}")
    print(f"Relative WER change from combined_short to combined_long: {relative_change(stats_dict['wer_combined_short'], stats_dict['wer_combined_long'])}")

# %%
corpus_stats_native = get_corpus_stats(df_native)
corpus_stats_foreign = get_corpus_stats(df_foreign)
corpus_stats_cleaned_native = get_corpus_stats(df_cleaned_native)
corpus_stats_cleaned_foreign = get_corpus_stats(df_cleaned_foreign)
corpus_stats_no_test = get_corpus_stats(df_native.query("dataset not in ['npsc_test', 'rundkast_test']"))

# %% [markdown]
# ### Scoring -- native speakers

# %%
print_corpus_stats(corpus_stats_native)
# Out:
# WER Rundkast: 18.1
# WER Stortinget: 16.8
# WER combined_short: 14.7
# WER combined_long: 13.4
# Relative WER change from Rundkast to combined_short: -18.8
# Relative WER change from Rundkast to combined_long: -26.0
# Relative WER change from Stortinget to combined_short: -12.5
# Relative WER change from Stortinget to combined_long: -20.2
# Relative WER change from combined_short to combined_long: -8.8

# %%
print_corpus_stats(corpus_stats_cleaned_native)
# Out:
# WER Rundkast: 16.5
# WER Stortinget: 16.0
# WER combined_short: 13.6
# WER combined_long: 12.2
# Relative WER change from Rundkast to combined_short: -17.6
# Relative WER change from Rundkast to combined_long: -26.1
# Relative WER change from Stortinget to combined_short: -15.0
# Relative WER change from Stortinget to combined_long: -23.8
# Relative WER change from combined_short to combined_long: -10.3

# %% [markdown]
# ### Scoring -- non-native speakers

# %%
print_corpus_stats(corpus_stats_foreign)
# Out:
# WER Rundkast: 35.1
# WER Stortinget: 35.4
# WER combined_short: 32.4
# WER combined_long: 31.5
# Relative WER change from Rundkast to combined_short: -7.7
# Relative WER change from Rundkast to combined_long: -10.3
# Relative WER change from Stortinget to combined_short: -8.5
# Relative WER change from Stortinget to combined_long: -11.0
# Relative WER change from combined_short to combined_long: -2.8

# %%
print_corpus_stats(corpus_stats_cleaned_foreign)
# Out:
# WER Rundkast: 33.7
# WER Stortinget: 34.8
# WER combined_short: 31.1
# WER combined_long: 29.9
# Relative WER change from Rundkast to combined_short: -7.7
# Relative WER change from Rundkast to combined_long: -11.3
# Relative WER change from Stortinget to combined_short: -10.6
# Relative WER change from Stortinget to combined_long: -14.1
# Relative WER change from combined_short to combined_long: -3.9

# %% [markdown]
# ## Scoring on the individual datasets

# %%
dataset_result_native = make_grouped_df(df_native, "dataset")
dataset_result_cleaned_native = make_grouped_df(df_cleaned_native, "dataset")

# %%
# Native speakers
dataset_result_native
# Out:
#                rundkast_wer  stortinget_wer  combined_short_wer  \
# dataset
# nbtale12               24.5            25.8                23.5
# nbtale3                28.9            25.8                24.4
# npsc_test              19.5             9.3                 9.9
# nst_test               10.6            11.2                 9.2
# rundkast_test          17.8            24.0                17.2
#
#                combined_long_wer  \
# dataset
# nbtale12                    21.9
# nbtale3                     23.0
# npsc_test                    7.9
# nst_test                     8.6
# rundkast_test               15.9
#
#                relative_change_rundkast_to_combined_short_wer  \
# dataset
# nbtale12                                                 -4.1
# nbtale3                                                 -15.6
# npsc_test                                               -49.2
# nst_test                                                -13.2
# rundkast_test                                            -3.4
#
#                relative_change_stortinget_to_combined_short_wer  \
# dataset
# nbtale12                                                   -8.9
# nbtale3                                                    -5.4
# npsc_test                                                   6.5
# nst_test                                                  -17.9
# rundkast_test                                             -28.3
#
#                relative_change_rundkast_to_combined_long_wer  \
# dataset
# nbtale12                                               -10.6
# nbtale3                                                -20.4
# npsc_test                                              -59.5
# nst_test                                               -18.9
# rundkast_test                                          -10.7
#
#                relative_change_stortinget_to_combined_long_wer  \
# dataset
# nbtale12                                                 -15.1
# nbtale3                                                  -10.9
# npsc_test                                                -15.1
# nst_test                                                 -23.2
# rundkast_test                                            -33.8
#
#                relative_change_combined_short_to_combined_long_wer
# dataset
# nbtale12                                                    -6.8
# nbtale3                                                     -5.7
# npsc_test                                                  -20.2
# nst_test                                                    -6.5
# rundkast_test                                               -7.6

# %%
dataset_result_cleaned_native
# Out:
#                rundkast_wer  stortinget_wer  combined_short_wer  \
# dataset
# nbtale12               22.5            25.3                21.7
# nbtale3                27.2            24.4                22.8
# npsc_test              17.4             8.8                 9.3
# nst_test                9.7            11.1                 8.7
# rundkast_test          16.0            21.1                15.4
#
#                combined_long_wer  \
# dataset
# nbtale12                    19.5
# nbtale3                     21.2
# npsc_test                    7.2
# nst_test                     7.8
# rundkast_test               14.1
#
#                relative_change_rundkast_to_combined_short_wer  \
# dataset
# nbtale12                                                 -3.6
# nbtale3                                                 -16.2
# npsc_test                                               -46.6
# nst_test                                                -10.3
# rundkast_test                                            -3.7
#
#                relative_change_stortinget_to_combined_short_wer  \
# dataset
# nbtale12                                                  -14.2
# nbtale3                                                    -6.6
# npsc_test                                                   5.7
# nst_test                                                  -21.6
# rundkast_test                                             -27.0
#
#                relative_change_rundkast_to_combined_long_wer  \
# dataset
# nbtale12                                               -13.3
# nbtale3                                                -22.1
# npsc_test                                              -58.6
# nst_test                                               -19.6
# rundkast_test                                          -11.9
#
#                relative_change_stortinget_to_combined_long_wer  \
# dataset
# nbtale12                                                 -22.9
# nbtale3                                                  -13.1
# npsc_test                                                -18.2
# nst_test                                                 -29.7
# rundkast_test                                            -33.2
#
#                relative_change_combined_short_to_combined_long_wer
# dataset
# nbtale12                                                   -10.1
# nbtale3                                                     -7.0
# npsc_test                                                  -22.6
# nst_test                                                   -10.3
# rundkast_test                                               -8.4

# %% [markdown]
# ### Scoring per dialect region

# %%
# Looking at the dialect results with only unplanned speech
region_results_nbtale3 = make_grouped_df(df.query("dataset == 'nbtale3'"), "region")
region_results_nbtale3
# Out:
#          rundkast_wer  stortinget_wer  combined_short_wer  combined_long_wer  \
# region
# east             22.3            21.5                19.3               18.2
# foreign          30.5            31.0                27.4               26.1
# mid              32.0            27.7                27.5               25.5
# north            27.1            24.6                22.9               21.5
# south            25.7            22.3                21.1               20.5
# west             32.7            28.6                27.2               25.8
#
#          relative_change_rundkast_to_combined_short_wer  \
# region
# east                                              -13.5
# foreign                                           -10.2
# mid                                               -14.1
# north                                             -15.5
# south                                             -17.9
# west                                              -16.8
#
#          relative_change_stortinget_to_combined_short_wer  \
# region
# east                                                -10.2
# foreign                                             -11.6
# mid                                                  -0.7
# north                                                -6.9
# south                                                -5.4
# west                                                 -4.9
#
#          relative_change_rundkast_to_combined_long_wer  \
# region
# east                                             -18.4
# foreign                                          -14.4
# mid                                              -20.3
# north                                            -20.7
# south                                            -20.2
# west                                             -21.1
#
#          relative_change_stortinget_to_combined_long_wer  \
# region
# east                                               -15.3
# foreign                                            -15.8
# mid                                                 -7.9
# north                                              -12.6
# south                                               -8.1
# west                                                -9.8
#
#          relative_change_combined_short_to_combined_long_wer
# region
# east                                                  -5.7
# foreign                                               -4.7
# mid                                                   -7.3
# north                                                 -6.1
# south                                                 -2.8
# west                                                  -5.1

# %% [markdown]
# ## Lexical analysis

# %%
def make_freqdist(wordlist):
     return sorted(Counter(wordlist).items(), key=lambda pair: pair[1], reverse=True)

# %%
df_native_nbtale_nst = df_native.copy().query("dataset not in ['npsc_test', 'rundkast_test']")
df_native_cleaned_nbtale_nst = df_cleaned_native.copy().query("dataset not in ['npsc_test', 'rundkast_test']")

def get_words_from_col(col):
    sentlist = col.tolist()
    return [x for y in sentlist for x in y.split(" ")]

df_words = df_native_nbtale_nst.dropna(subset=["standardized_text", "rundkast_model", "stortinget_model", "combined_short_model", "combined_long_model"])
reference_wds = get_words_from_col(df_words.standardized_text)
rundkast_wds = get_words_from_col(df_words["rundkast_model"])
stortinget_wds = get_words_from_col(df_words["stortinget_model"])
combined_short_wds = get_words_from_col(df_words["combined_short_model"])
combined_long_wds = get_words_from_col(df_words["combined_long_model"])

# %%
#Make frequency word lists (native only)
ref_wdcount = make_freqdist(reference_wds)
rundkast_wdcount = make_freqdist(rundkast_wds)
stortinget_wdcount = make_freqdist(stortinget_wds)
combined_short_wdcount = make_freqdist(combined_short_wds)
combined_long_wdcount = make_freqdist(combined_long_wds)

# %%
def make_lexicon_df(list_of_freqdists, list_of_names):
    mydict = {}
    for dist, name in zip(list_of_freqdists, list_of_names):
        for word, n in dist:
            if word not in mydict.keys():
                mydict[word] = {nm: 0 for nm in list_of_names}
            mydict[word][name] += n
    return pd.DataFrame(mydict).transpose()

# %%
wordfreq_df = make_lexicon_df([ref_wdcount, rundkast_wdcount, stortinget_wdcount, combined_short_wdcount, combined_long_wdcount], ["reference", "rundkast", "stortinget", "combined_short", "combined_long"])

# %%
def make_keyness_df(freq_df, ref_col, compare_col):
    """Keyness computation following this: https://alvinntnu.github.io/NTNU_ENC2036_LECTURES/keyword-analysis.html#computing-keynesss"""
    print()
    keyness_df = freq_df[[ref_col, compare_col]].copy()
    keyness_df.columns = ["reference", "comparison"]
    keyness_df["reference_other"] = keyness_df["reference"].sum()-keyness_df["reference"]
    keyness_df["comparison_other"] = keyness_df["comparison"].sum()-keyness_df["comparison"]
    row_sum_word = keyness_df["reference"] + keyness_df["comparison"]
    row_sum_other = keyness_df["reference_other"] + keyness_df["comparison_other"]
    column_sum_ref = keyness_df["reference"] + keyness_df["reference_other"]
    column_sum_comp = keyness_df["comparison"] + keyness_df["comparison_other"]
    table_sum = row_sum_word + row_sum_other
    keyness_df["reference_exp"] = (row_sum_word * column_sum_ref) / table_sum
    keyness_df["comparison_exp"] = (row_sum_word * column_sum_comp) / table_sum
    keyness_df["reference_other_exp"] = (row_sum_other * column_sum_ref) / table_sum
    keyness_df["comparison_other_exp"] = (row_sum_other * column_sum_comp) / table_sum
    keyness_df["log_likelihood"] = keyness_df.apply(lambda x: power_divergence(f_obs=(x["reference"], x["comparison"], x["reference_other"], x["comparison_other"]), f_exp=(x["reference_exp"], x["comparison_exp"], x["reference_other_exp"], x["comparison_other_exp"]), lambda_=0, ddof=1)[0], axis=1)
    keyness_df["chi_square"] = keyness_df.apply(lambda x: power_divergence(f_obs=(x["reference"], x["comparison"], x["reference_other"], x["comparison_other"]), f_exp=(x["reference_exp"], x["comparison_exp"], x["reference_other_exp"], x["comparison_other_exp"]), lambda_=0, ddof=1)[1], axis=1)
    keyness_df = keyness_df[["reference", "comparison", "log_likelihood", "chi_square"]]
    keyness_df["more_freq_in_comp"] = keyness_df["reference"]/keyness_df["reference"].sum() < keyness_df["comparison"]/keyness_df["comparison"].sum()
    return keyness_df

# %%
rundkast_keyness_df = make_keyness_df(wordfreq_df, "reference", "rundkast")
stortinget_keyness_df = make_keyness_df(wordfreq_df, "reference", "stortinget")
combined_short_keyness_df = make_keyness_df(wordfreq_df, "reference", "combined_short")
combined_long_keyness_df = make_keyness_df(wordfreq_df, "reference", "combined_long")
# Out:
# /home/pers/.pyenv/versions/scribe/lib/python3.8/site-packages/scipy/stats/_stats_py.py:6769: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# /home/pers/.pyenv/versions/scribe/lib/python3.8/site-packages/scipy/stats/_stats_py.py:6769: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# /home/pers/.pyenv/versions/scribe/lib/python3.8/site-packages/scipy/stats/_stats_py.py:6769: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# /home/pers/.pyenv/versions/scribe/lib/python3.8/site-packages/scipy/stats/_stats_py.py:6769: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# /home/pers/.pyenv/versions/scribe/lib/python3.8/site-packages/scipy/stats/_stats_py.py:6769: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# /home/pers/.pyenv/versions/scribe/lib/python3.8/site-packages/scipy/stats/_stats_py.py:6769: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# /home/pers/.pyenv/versions/scribe/lib/python3.8/site-packages/scipy/stats/_stats_py.py:6769: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# /home/pers/.pyenv/versions/scribe/lib/python3.8/site-packages/scipy/stats/_stats_py.py:6769: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)

# %%
def highlight_rows(row):
    if row["more_freq_in_comp"]:
        color = '#fa0000' # Red
    else:
        color = '#1F18C0' # Blue
    return ['background-color: {}'.format(color) for r in row]

# %% [markdown]
# The log-likelihood score indicates how typical or atypical a term is in the compared corpus relative to the target corpus. Words with higher numbers are more typical/atypical for the compared corpus, while words with low numbers are more similar to the compared corpus. Since both typical and atypical words get high numbers, it makes sense to look at the frequency in both corpora too.

# %%
# Stortinget relative to ground truth
# Red = more frequent in Stortinget

pd.set_option('display.max_rows', 100)
stortinget_keyness_df.sort_values(by="log_likelihood", ascending=False).head(100).style.apply(highlight_rows, axis=1)
# Out:
# <style type="text/css">
# #T_20b32_row0_col0, #T_20b32_row0_col1, #T_20b32_row0_col2, #T_20b32_row0_col3, #T_20b32_row0_col4, #T_20b32_row2_col0, #T_20b32_row2_col1, #T_20b32_row2_col2, #T_20b32_row2_col3, #T_20b32_row2_col4, #T_20b32_row3_col0, #T_20b32_row3_col1, #T_20b32_row3_col2, #T_20b32_row3_col3, #T_20b32_row3_col4, #T_20b32_row4_col0, #T_20b32_row4_col1, #T_20b32_row4_col2, #T_20b32_row4_col3, #T_20b32_row4_col4, #T_20b32_row6_col0, #T_20b32_row6_col1, #T_20b32_row6_col2, #T_20b32_row6_col3, #T_20b32_row
row67_col0, #T_0d1c8_row67_col1, #T_0d1c8_row67_col2, #T_0d1c8_row67_col3, #T_0d1c8_row67_col4, #T_0d1c8_row68_col0, #T_0d1c8_row68_col1, #T_0d1c8_row68_col2, #T_0d1c8_row68_col3, #T_0d1c8_row68_col4, #T_0d1c8_row69_col0, #T_0d1c8_row69_col1, #T_0d1c8_row69_col2, #T_0d1c8_row69_col3, #T_0d1c8_row69_col4, #T_0d1c8_row70_col0, #T_0d1c8_row70_col1, #T_0d1c8_row70_col2, #T_0d1c8_row70_col3, #T_0d1c8_row70_col4, #T_0d1c8_row71_col0, #T_0d1c8_row71_col1, #T_0d1c8_row71_col2, #T_0d1c8_row71_col3, #T_0d1c8_row71_col4, #T_0d1c8_row75_col0, #T_0d1c8_row75_col1, #T_0d1c8_row75_col2, #T_0d1c8_row75_col3, #T_0d1c8_row75_col4, #T_0d1c8_row76_col0, #T_0d1c8_row76_col1, #T_0d1c8_row76_col2, #T_0d1c8_row76_col3, #T_0d1c8_row76_col4, #T_0d1c8_row77_col0, #T_0d1c8_row77_col1, #T_0d1c8_row77_col2, #T_0d1c8_row77_col3, #T_0d1c8_row77_col4, #T_0d1c8_row80_col0, #T_0d1c8_row80_col1, #T_0d1c8_row80_col2, #T_0d1c8_row80_col3, #T_0d1c8_row80_col4, #T_0d1c8_row81_col0, #T_0d1c8_row81_col1 ...
#   background-color: #1F18C0;
# }
# #T_0d1c8_row4_col0, #T_0d1c8_row4_col1, #T_0d1c8_row4_col2, #T_0d1c8_row4_col3, #T_0d1c8_row4_col4, #T_0d1c8_row6_col0, #T_0d1c8_row6_col1, #T_0d1c8_row6_col2, #T_0d1c8_row6_col3, #T_0d1c8_row6_col4, #T_0d1c8_row8_col0, #T_0d1c8_row8_col1, #T_0d1c8_row8_col2, #T_0d1c8_row8_col3, #T_0d1c8_row8_col4, #T_0d1c8_row9_col0, #T_0d1c8_row9_col1, #T_0d1c8_row9_col2, #T_0d1c8_row9_col3, #T_0d1c8_row9_col4, #T_0d1c8_row10_col0, #T_0d1c8_row10_col1, #T_0d1c8_row10_col2, #T_0d1c8_row10_col3, #T_0d1c8_row10_col4, #T_0d1c8_row11_col0, #T_0d1c8_row11_col1, #T_0d1c8_row11_col2, #T_0d1c8_row11_col3, #T_0d1c8_row11_col4, #T_0d1c8_row12_col0, #T_0d1c8_row12_col1, #T_0d1c8_row12_col2, #T_0d1c8_row12_col3, #T_0d1c8_row12_col4, #T_0d1c8_row13_col0, #T_0d1c8_row13_col1, #T_0d1c8_row13_col2, #T_0d1c8_row13_col3, #T_0d1c8_row13_col4, #T_0d1c8_row16_col0, #T_0d1c8_row16_col1, #T_0d1c8_row16_col2, #T_0d1c8_row16_col3, #T_0d1c8_row16_col4, #T_0d1c8_row18_col0, #T_0d1c8_row18_col1, #T_0d1c8_row18_col2, #T_0d1c8_row18_col3, #T_0d1c8_row18_col4, #T_0d1c8_row19_col0, #T_0d1c8_row19_col1, #T_0d1c8_row19_col2, #T_0d1c8_row19_col3, #T_0d1c8_row19_col4, #T_0d1c8_row20_col0, #T_0d1c8_row20_col1, #T_0d1c8_row20_col2, #T_0d1c8_row20_col3, #T_0d1c8_row20_col4, #T_0d1c8_row21_col0, #T_0d1c8_row21_col1, #T_0d1c8_row21_col2, #T_0d1c8_row21_col3, #T_0d1c8_row21_col4, #T_0d1c8_row22_col0, #T_0d1c8_row22_col1, #T_0d1c8_row22_col2, #T_0d1c8_row22_col3, #T_0d1c8_row22_col4, #T_0d1c8_row23_col0, #T_0d1c8_row23_col1, #T_0d1c8_row23_col2, #T_0d1c8_row23_col3, #T_0d1c8_row23_col4, #T_0d1c8_row24_col0, #T_0d1c8_row24_col1, #T_0d1c8_row24_col2, #T_0d1c8_row24_col3, #T_0d1c8_row24_col4, #T_0d1c8_row28_col0, #T_0d1c8_row28_col1, #T_0d1c8_row28_col2, #T_0d1c8_row28_col3, #T_0d1c8_row28_col4, #T_0d1c8_row29_col0, #T_0d1c8_row29_col1, #T_0d1c8_row29_col2, #T_0d1c8_row29_col3, #T_0d1c8_row29_col4, #T_0d1c8_row30_col0, #T_0d1c8_row30_col1, #T_0d1c8_row30_col2, #T_0d1c8_row30_col3, #T_0d1c8_row30_col4, #T_0d1c8_row31_col0, #T_0d1c8_row31_col1, #T_0d1c8_row31_col2, #T_0d1c8_row31_col3, #T_0d1c8_row31_col4, #T_0d1c8_row33_col0, #T_0d1c8_row33_col1, #T_0d1c8_row33_col2, #T_0d1c8_row33_col3, #T_0d1c8_row33_col4, #T_0d1c8_row34_col0, #T_0d1c8_row34_col1, #T_0d1c8_row34_col2, #T_0d1c8_row34_col3, #T_0d1c8_row34_col4, #T_0d1c8_row35_col0, #T_0d1c8_row35_col1, #T_0d1c8_row35_col2, #T_0d1c8_row35_col3, #T_0d1c8_row35_col4, #T_0d1c8_row38_col0, #T_0d1c8_row38_col1, #T_0d1c8_row38_col2, #T_0d1c8_row38_col3, #T_0d1c8_row38_col4, #T_0d1c8_row39_col0, #T_0d1c8_row39_col1, #T_0d1c8_row39_col2, #T_0d1c8_row39_col3, #T_0d1c8_row39_col4, #T_0d1c8_row43

# %%
combined_short_keyness_df.sort_values(by="log_likelihood", ascending=False).head(100).style.apply(highlight_rows, axis=1)
# Out:
# <style type="text/css">
# #T_56ee2_row0_col0, #T_56ee2_row0_col1, #T_56ee2_row0_col2, #T_56ee2_row0_col3, #T_56ee2_row0_col4, #T_56ee2_row2_col0, #T_56ee2_row2_col1, #T_56ee2_row2_col2, #T_56ee2_row2_col3, #T_56ee2_row2_col4, #T_56ee2_row3_col0, #T_56ee2_row3_col1, #T_56ee2_row3_col2, #T_56ee2_row3_col3, #T_56ee2_row3_col4, #T_56ee2_row4_col0, #T_56ee2_row4_col1, #T_56ee2_row4_col2, #T_56ee2_row4_col3, #T_56ee2_row4_col4, #T_56ee2_row5_col0, #T_56ee2_row5_col1, #T_56ee2_row5_col2, #T_56ee2_row5_col3, #T_56ee2_row5_col4, #T_56ee2_row11_col0, #T_56ee2_row11_col1, #T_56ee2_row11_col2, #T_56ee2_row11_col3, #T_56ee2_row11_col4, #T_56ee2_row13_col0, #T_56ee2_row13_col1, #T_56ee2_row13_col2, #T_56ee2_row13_col3, #T_56ee2_row13_col4, #T_56ee2_row23_col0, #T_56ee2_row23_col1, #T_56ee2_row23_col2, #T_56ee2_row23_col3, #T_56ee2_row23_col4, #T_56ee2_row24_col0, #T_56ee2_row24_col1, #T_56ee2_row24_col2, #T_56ee2_row24_col3, #T_56ee2_row24_col4, #T_56ee2_row25_col0, #T_56ee2_row25_col1, #T_56ee2_row25_col2, #T_56ee2_row25_col3, #T_56ee2_row25_col4, #T_56ee2_row26_col0, #T_56ee2_row26_col1, #T_56ee2_row26_col2, #T_56ee2_row26_col3, #T_56ee2_row26_col4, #T_56ee2_row27_col0, #T_56ee2_row27_col1, #T_56ee2_row27_col2, #T_56ee2_row27_col3, #T_56ee2_row27_col4, #T_56ee2_row31_col0, #T_56ee2_row31_col1, #T_56ee2_row31_col2, #T_56ee2_row31_col3, #T_56ee2_row31_col4, #T_56ee2_row35_col0, #T_56ee2_row35_col1, #T_56ee2_row35_col2, #T_56ee2_row35_col3, #T_56ee2_row35_col4, #T_56ee2_row37_col0, #T_56ee2_row37_col1, #T_56ee2_row37_col2, #T_56ee2_row37_col3, #T_56ee2_row37_col4, #T_56ee2_row38_col0, #T_56ee2_row38_col1, #T_56ee2_row38_col2, #T_56ee2_row38_col3, #T_56ee2_row38_col4, #T_56ee2_row39_col0, #T_56ee2_row39_col1, #T_56ee2_row39_col2, #T_56ee2_row39_col3, #T_56ee2_row39_col4, #T_56ee2_row40_col0, #T_56ee2_row40_col1, #T_56ee2_row40_col2, #T_56ee2_row40_col3, #T_56ee2_row40_col4, #T_56ee2_row42_col0, #T_56ee2_row42_col1, #T_56ee2_row42_col2, #T_56ee2_row42_col3, #T_56ee2_row42_col4, #T_56ee2_row43_col0, #T_56ee2_row43_col1, #T_56ee2_row43_col2, #T_56ee2_row43_col3, #T_56ee2_row43_col4, #T_56ee2_row44_col0, #T_56ee2_row44_col1, #T_56ee2_row44_col2, #T_56ee2_row44_col3, #T_56ee2_row44_col4, #T_56ee2_row47_col0, #T_56ee2_row47_col1, #T_56ee2_row47_col2, #T_56ee2_row47_col3, #T_56ee2_row47_col4, #T_56ee2_row50_col0, #T_56ee2_row50_col1, #T_56ee2_row50_col2, #T_56ee2_row50_col3, #T_56ee2_row50_col4, #T_56ee2_row55_col0, #T_56ee2_row55_col1, #T_56ee2_row55_col2, #T_56ee2_row55_col3, #T_56ee2_row55_col4, #T_56ee2_row57_col0, #T_56ee2_row57_col1, #T_56ee2_row57_col2, #T_56ee2_row57_col3, #T_56ee2_row57_col4, #T_56ee2_row58_col0, #T_56ee2_row58_col1, #T_56ee2_row58_col2, #T_56ee2_row58_col3, #T_56ee2_row58_col4, #T_56ee2_row59_col0, #T_56ee2_row59_col1, #T_56ee2_row59_col2, #T_56ee2_row59_col3, #T_56ee2_row59_col4, #T_56ee2_row60_col0, #T_56ee2_row60_col1, #T_56ee2_row60_col2, #T_56ee2_row60_col3, #T_56ee2_row60_col4, #T_56ee2_row62_col0, #T_56ee2_row62_col1, #T_56ee2_row62_col2, #T_56ee2_row62_col3, #T_56ee2_row62_col4, #T_56ee2_row63_col0, #T_56ee2_row63_col1, #T_56ee2_row63_col2, #T_56ee2_row63_col3, #T_56ee2_row63_col4, #T_56ee2_row64_col0, #T_56ee2_row64_col1, #T_56ee2_row64_col2, #T_56ee2_row64_col3, #T_56ee2_row64_col4, #T_56ee2_row65_col0, #T_56ee2_row65_col1, #T_56ee2_row65_col2, #T_56ee2_row65_col3, #T_56ee2_row65_col4, #T_56ee2_row68_col0, #T_56ee2_row68_col1, #T_56ee2_row68_col2, #T_56ee2_row68_col3, #T_56ee2_row68_col4, #T_56ee2_row69_col0, #T_56ee2_row69_col1, #T_56ee2_row69_col2, #T_56ee2_row69_col3, #T_56ee2_row69_col4, #T_56ee2_row70_col0, #T_56ee2_row70_col1, #T_56ee2_row70_col2, #T_56ee2_row70_col3, #T_56ee2_row70_col4, #T_56ee2_row71_col0, #T_56ee2_row71_col1, #T_56ee2_row71_col2, #T_56ee2_row71_col3, #T_56ee2_row71_col4, #T_56ee2_row72_col0, #T_56ee2_row72_col1, #T_56ee2_row72_col2, #T_56ee2_row72_col3, #T_56ee2_row72_col4, #T_56ee2_row73_col0, #T_56ee2_row73_col1, #T_56ee2_row73_col2, #T_56ee2_row73_col3, #T_56ee2_row73_col4, #T_56ee2_row74_col0, #T_56ee2_row74 ...
#   background-color: #1F18C0;
# }
# #T_56ee2_row1_col0, #T_56ee2_row1_col1, #T_56ee2_row1_col2, #T_56ee2_row1_col3, #T_56ee2_row1_col4, #T_56ee2_row6_col0, #T_56ee2_row6_col1, #T_56ee2_row6_col2, #T_56ee2_row6_col3, #T_56ee2_row6_col4, #T_56ee2_row7_col0, #T_56ee2_row7_col1, #T_56ee2_row7_col2, #T_56ee2_row7_col3, #T_56ee2_row7_col4, #T_56ee2_row8_col0, #T_56ee2_row8_col1, #T_56ee2_row8_col2, #T_56ee2_row8_col3, #T_56ee2_row8_col4, #T_56ee2_row9_col0, #T_56ee2_row9_col1, #T_56ee2_row9_col2, #T_56ee2_row9_col3, #T_56ee2_row9_col4, #T_56ee2_row10_col0, #T_56ee2_row10_col1, #T_56ee2_row10_col2, #T_56ee2_row10_col3, #T_56ee2_row10_col4, #T_56ee2_row12_col0, #T_56ee2_row12_col1, #T_56ee2_row12_col2, #T_56ee2_row12_col3, #T_56ee2_row12_col4, #T_56ee2_row14_col0, #T_56ee2_row14_col1, #T_56ee2_row14_col2, #T_56ee2_row14_col3, #T_56ee2_row14_col4, #T_56ee2_row15_col0, #T_56ee2_row15_col1, #T_56ee2_row15_col2, #T_56ee2_row15_col3, #T_56ee2_row15_col4, #T_56ee2_row16_col0, #T_56ee2_row16_col1, #T_56ee2_row16_col2, #T_56ee2_row16_col3, #T_56ee2_row16_col4, #T_56ee2_row17_col0, #T_56ee2_row17_col1, #T_56ee2_row17_col2, #T_56ee2_row17_col3, #T_56ee2_row17_col4, #T_56ee2_row18_col0, #T_56ee2_row18_col1, #T_56ee2_row18_col2, #T_56ee2_row18_col3, #T_56ee2_row18_col4, #T_56ee2_row19_col0, #T_56ee2_row19_col1, #T_56ee2_row19_col2, #T_56ee2_row19_col3, #T_56ee2_row19_col4, #T_56ee2_row20_col0, #T_56ee2_row20_col1, #T_56ee2_row20_col2, #T_56ee2_row20_col3, #T_56ee2_row20_col4, #T_56ee2_row21_col0, #T_56ee2_row21_col1, #T_56ee2_row21_col2, #T_56ee2_row21_col3, #T_56ee2_row21_col4, #T_56ee2_row22_col0, #T_56ee2_row22_col1, #T_56ee2_row22_col2, #T_56ee2_row22_col3, #T_56ee2_row22_col4, #T_56ee2_row28_col0, #T_56ee2_row28_col1, #T_56ee2_row28_col2, #T_56ee2_row28_col3, #T_56ee2_row28_col4, #T_56ee2_row29_col0, #T_56ee2_row29_col1, #T_56ee2_row29_col2, #T_56ee2_row29_col3, #T_56ee2_row29_col4, #T_56ee2_row30_col0, #T_56ee2_row30_col1, #T_56ee2_row30_col2, #T_56ee2_row30_col3, #T_56ee2_row30_col4, #T_56ee2_row32_col0, #T_56ee2_row32_col1, #T_56ee2_row32_col2, #T_56ee2_row32_col3, #T_56ee2_row32_col4, #T_56ee2_row33_col0, #T_56ee2_row33_col1, #T_56ee2_row33_col2, #T_56ee2_row33_col3, #T_56ee2_row33_col4, #T_56ee2_row34_col0, #T_56ee2_row34_col1, #T_56ee2_row34_col2, #T_56ee2_row34_col3, #T_56ee2_row34_col4, #T_56ee2_row36_col0, #T_56ee2_row36_col1, #T_56ee2_row36_col2, #T_56ee2_row36_col3, #T_56ee2_row36_col4, #T_56ee2_row41_col0, #T_56ee2_row41_col1, #T_56ee2_row41_col2, #T_56ee2_row41_col3, #T_56ee2_row41_col4, #T_56ee2_row45

# %%
combined_long_keyness_df.sort_values(by="log_likelihood", ascending=False).head(100).style.apply(highlight_rows, axis=1)
# Out:
# <style type="text/css">
# #T_a3ba1_row0_col0, #T_a3ba1_row0_col1, #T_a3ba1_row0_col2, #T_a3ba1_row0_col3, #T_a3ba1_row0_col4, #T_a3ba1_row1_col0, #T_a3ba1_row1_col1, #T_a3ba1_row1_col2, #T_a3ba1_row1_col3, #T_a3ba1_row1_col4, #T_a3ba1_row2_col0, #T_a3ba1_row2_col1, #T_a3ba1_row2_col2, #T_a3ba1_row2_col3, #T_a3ba1_row2_col4, #T_a3ba1_row4_col0, #T_a3ba1_row4_col1, #T_a3ba1_row4_col2, #T_a3ba1_row4_col3, #T_a3ba1_row4_col4, #T_a3ba1_row5_col0, #T_a3ba1_row5_col1, #T_a3ba1_row5_col2, #T_a3ba1_row5_col3, #T_a3ba1_row5_col4, #T_a3ba1_row10_col0, #T_a3ba1_row10_col1, #T_a3ba1_row10_col2, #T_a3ba1_row10_col3, #T_a3ba1_row10_col4, #T_a3ba1_row18_col0, #T_a3ba1_row18_col1, #T_a3ba1_row18_col2, #T_a3ba1_row18_col3, #T_a3ba1_row18_col4, #T_a3ba1_row20_col0, #T_a3ba1
a3ba1_row60_col3, #T_a3ba1_row60_col4, #T_a3ba1_row61_col0, #T_a3ba1_row61_col1, #T_a3ba1_row61_col2, #T_a3ba1_row61_col3, #T_a3ba1_row61_col4, #T_a3ba1_row62_col0, #T_a3ba1_row62_col1, #T_a3ba1_row62_col2, #T_a3ba1_row62_col3, #T_a3ba1_row62_col4, #T_a3ba1_row63_col0, #T_a3ba1_row63_col1, #T_a3ba1_row63_col2, #T_a3ba1_row63_col3, #T_a3ba1_row63_col4, #T_a3ba1_row64_col0, #T_a3ba1_row64_col1, #T_a3ba1_row64_col2, #T_a3ba1_row64_col3, #T_a3ba1_row64_col4, #T_a3ba1_row65_col0, #T_a3ba1_row65_col1, #T_a3ba1_row65_col2, #T_a3ba1_row65_col3, #T_a3ba1_row65_col4, #T_a3ba1_row70_col0, #T_a3ba1_row70_col1, #T_a3ba1_row70_col2, #T_a3ba1_row70_col3, #T_a3ba1_row70_col4, #T_a3ba1_row72_col0, #T_a3ba1_row72_col1, #T_a3ba1_row72_col2, #T_a3ba1_row72_col3, #T_a3ba1_row72_col4, #T_a3ba1_row73_col0, #T_a3ba1_row73_col1, #T_a3ba1_row73_col2, #T_a3ba1_row73_col3, #T_a3ba1_row73_col4, #T_a3ba1_row78_col0, #T_a3ba1_row78_col1, #T_a3ba1_row78_col2, #T_a3ba1_row78_col3, #T_a3ba1_row78_col4, #T_a3ba1_row79_col0, #T_a3ba1_row79_col1, #T_a3ba1_row79_col2, #T_a3ba1_row79_col3, #T_a3ba1_row79_col4, #T_a3ba1_row81_col0, #T_a3ba1_row81 ...
#   background-color: #1F18C0;
# }
# #T_a3ba1_row3_col0, #T_a3ba1_row3_col1, #T_a3ba1_row3_col2, #T_a3ba1_row3_col3, #T_a3ba1_row3_col4, #T_a3ba1_row6_col0, #T_a3ba1_row6_col1, #T_a3ba1_row6_col2, #T_a3ba1_row6_col3, #T_a3ba1_row6_col4, #T_a3ba1_row7_col0, #T_a3ba1_row7_col1, #T_a3ba1_row7_col2, #T_a3ba1_row7_col3, #T_a3ba1_row7_col4, #T_a3ba1_row8_col0, #T_a3ba1_row8_col1, #T_a3ba1_row8_col2, #T_a3ba1_row8_col3, #T_a3ba1_row8_col4, #T_a3ba1_row9_col0, #T_a3ba1_row9_col1, #T_a3ba1_row9_col2, #T_a3ba1_row9_col3, #T_a3ba1_row9_col4, #T_a3ba1_row11_col0, #T_a3ba1_row11_col1, #T_a3ba1_row11_col2, #T_a3ba1_row11_col3, #T_a3ba1_row11_col4, #T_a3ba1_row12_col0, #T_a3ba1_row12_col1, #T_a3ba1_row12_col2, #T_a3ba1_row12_col3, #T_a3ba1_row12_col4, #T_a3ba1_row13_col0, #T_a3ba1_row13_col1, #T_a3ba1_row13_col2, #T_a3ba1_row13_col3, #T_a3ba1_row13_col4, #T_a3ba1_row14_col0, #T_a3ba1_row14_col1, #T_a3ba1_row14_col2, #T_a3ba1_row14_col3, #T_a3ba1_row14_col4, #T_a3ba1_row15_col0, #T_a3ba1_row15_col1, #T_a3ba1_row15_col2, #T_a3ba1_row15_col3, #T_a3ba1_row15_col4, #T_a3ba1_row16_col0, #T_a3ba1_row16_col1, #T_a3ba1_row16_col2, #T_a3ba1_row16_col3, #T_a3ba1_row16_col4, #T_a3ba1_row17_col0, #T_a3ba1_row17_col1, #T_a3ba1_row17_col2, #T_a3ba1_row17_col3, #T_a3ba1_row17_col4, #T_a3ba1_row19_col0, #T_a3ba1_row19_col1, #T_a3ba1_row19_col2, #T_a3ba1_row19_col3, #T_a3ba1_row19_col4, #T_a3ba1_row21_col0, #T_a3ba1_row21_col1, #T_a3ba1_row21_col2, #T_a3ba1_row21_col3, #T_a3ba1_row21_col4, #T_a3ba1_row23_col0, #T_a3ba1_row23_col1, #T_a3ba1_row23_col2, #T_a3ba1_row23_col3, #T_a3ba1_row23_col4, #T_a3ba1_row24_col0, #T_a3ba1_row24_col1, #T_a3ba1_row24_col2, #T_a3ba1_row24_col3, #T_a3ba1_row24_col4, #T_a3ba1_row27_col0, #T_a3ba1_row27_col1, #T_a3ba1_row27_col2, #T_a3ba1_row27_col3, #T_a3ba1_row27_col4, #T_a3ba1_row28_col0, #T_a3ba1_row28_col1, #T_a3ba1_row28_col2, #T_a3ba1_row28_col3, #T_a3ba1_row28_col4, #T_a3ba1_row29_col0, #T_a3ba1_row29_col1, #T_a3ba1_row29_col2, #T_a3ba1_row29_col3, #T_a3ba1_row29_col4, #T_a3ba1_row31_col0, #T_a3ba1_row31_col1, #T_a3ba1_row31_col2, #T_a3ba1_row31_col3, #T_a3ba1_row31_col4, #T_a3ba1_row34_col0, #T_a3ba1_row34_col1, #T_a3ba1_row34_col2, #T_a3ba1_row34_col3, #T_a3ba1_row34_col4, #T_a3ba1_row37_col0, #T_a3ba1_row37_col1, #T_a3ba1_row37_col2, #T_a3ba1_row37_col3, #T_a3ba1_row37_col4, #T_a3ba1_row38_col0, #T_a3ba1_row38_col1, #T_a3ba1_row38_col2, #T_a3ba1_row38_col3, #T_a3ba1_row38_col4, #T_a3ba1_row39_col0, #T_a3ba1_row39_col1, #T_a3ba1_row39_col2, #T_a3ba1_row39_col3, #T_a3ba1_row39_col4, #T_a3ba1_row41_col0, #T_a3ba1_row41_col1, #T_a3ba1_row41_col2, #T_a3ba1_row41_col3, #T_a3ba1_row41_col4, #T_a3ba1_row44_col0, #T_a3ba1_row44_col1, #T_a3ba1_row44_col2, #T_a3ba1_row44_col3, #T_a3ba1_row44_col4, #T_a3ba1_row46_col0, #T_a3ba1_row46_col1, #T_a3ba1_row46_col2, #T_a3ba1_row46_col3, #T_a3ba1_row46_col4, #T_a3ba1_row47_col0, #T_a3ba1_row47_col1, #T_a3ba1_row47_col2, #T_a3ba1_row47_col3, #T_a3ba1_row47_col4, #T_a3ba1_row51_col0, #T_a3ba1_row51_col1, #T_a3ba1_row51_col2, #T_a3ba1_row51_col3, #T_a3ba1_row51_col4, #T_a3ba1_row52

# %% [markdown]
# ## Hapax analysis

# %%
hap_ref = wordfreq_df.query('reference == 1')
hap_rundkast = wordfreq_df.query('rundkast == 1')
hap_stortinget = wordfreq_df.query('stortinget == 1')
hap_combined_short = wordfreq_df.query('combined_short == 1')
hap_combined_long = wordfreq_df.query('combined_long == 1')

# %%
print(f"number of hapaces in ground truth: {hap_ref.reference.count()}")
print(f"number of hapaces in Rundkast: {hap_rundkast.reference.count()}")
print(f"number of hapaces in Stortinget: {hap_stortinget.reference.count()}")
print(f"number of hapaces in Combined Short: {hap_combined_short.reference.count()}")
print(f"number of hapaces in Combined Long: {hap_combined_long.reference.count()}")
# Out:
# number of hapaces in ground truth: 9672
# number of hapaces in Rundkast: 20215
# number of hapaces in Stortinget: 20591
# number of hapaces in Combined Short: 18676
# number of hapaces in Combined Long: 17613

# %%
hap_rundkast.query("reference == 0").sample(100, random_state=1)
# Out:
#                          reference  rundkast  stortinget  combined_short  \
# diplomet                         0         1           0               1
# nabu                             0         1           1               1
# indresogen                       0         1           1               1
# kunstakademis                    0         1           0               0
# norden                           0         1           1               2
# clubstør                         0         1           0               0
# rash                             0         1           0               0
# job                              0         1           0               0
# hemstemvet                       0         1           0               0
# avturgåerne                      0         1           0               0
# katteunger                       0         1           0               0
# eiendoms-etaten                  0         1           0               1
# dyrekjør                         0         1           0               0
# misforståtd                      0         1           0               0
# kalia                            0         1           0               0
# høygtalereneee                   0         1           0               0
# retiner                          0         1           1               0
# bisadresser                      0         1           0               0
# ytuns-politikk                   0         1           1               0
# bøgd                             0         1           0               3
# stillesert                       0         1           0               0
# sreiner                          0         1           1               1
# nåri                             0         1           0               1
# forretnings-forbindelse          0         1           0               1
# forfatnings-domstolen            0         1           0               0
# diologien                        0         1           0               0
# takttk                           0         1           0               0
# tekstil-kunstnere                0         1           0               0
# tou-treckingvvv                  0         1           0               0
# hmes                             0         1           0               0
# oksid                            0         1           0               0
# gurku                            0         1           0               0
# kome                             0         1           2               0
# sjebner                          0         1           0               2
# tennes-klubb                     0         1           0               0
# ukefordi                         0         1           0               0
# autumatkassen                    0         1           1               1
# plangåenden                      0         1           0               0
# gåren                            0         1           1               1
# ubarbeirt                        0         1           0               0
# oppmerksommen                    0         1           0               0
# fiv                              0         1           1               1
# passasjerdøyntj                  0         1           0               0
# skarret                          0         1           0               0
# jass-musikken                    0         1           0               1
# staslig                          0         1           1               1
# atmosfæret                       0         1           0               0
# bordelb                          0         1           0               0
# matl                             0         1           0               2
# malgarm                          0         1           0               0
# øyte                             0         1           1               1
# eeeav                            0         1           0               0
# hangikk                          0         1           0               0
# ayithuns-politikk                0         1           0               0
# deeltidsarbeidene                0         1           1               0
# boyer                            0         1           2               1
# forsjelgere                      0         1           0               0
# milliard-beløp                   0         1           0               1
# brundsen                         0         1           0               0
# krayef                           0         1           0               0
# kjempe-artig                     0         1           0               1
# krangle                          0         1           0               0
# tsja                             0         1           0               0
# turistaktraksjon                 0         1           1               0
# forståkete                       0         1           1               1
# jyda                             0         1           0               1
# gaer                             0         1           0               0
# dyrekjærr                        0         1           0               1
# marla                            0         1           0               1
# sekxs-lærere                     0         1           0               0
# studian                          0         1           0               1
# plutselg                         0         1           0               0
# bilee                            0         1           0               0
# diste                            0         1           0               0
# godtur                           0         1           0               0
# sommaertid                       0         1           0               0
# perlemorskyer                    0         1           0               1
# forelesinger                     0         1           1               1
# altsett                          0         1           0               1
# teby                             0         1           0               0
# bortsendte                       0         1           1               1
# vanliga                          0         1           0               0
# januar-kullen                    0         1           0               1
# oawards                          0         1           0               0
# gjegotjeneste                    0         1           0               0
# marebakken                       0         1           1               1
# premiært                         0         1           0               1
# dannelses-begrepet               0         1           0               1
# iatoy                            0         1           0               0
# fjok                             0         1           0               0
# plagånn                          0         1           0               0
# stockmour                        0         1           0               2
# povepoynt                        0         1           0               0
# sykleren                         0         1           0               0
# pbortvin                         0         1           0               0
# slenge                           0         1           0               0
# tengninger                       0         1           0               1
# øren                             0         1           2               2
# alt-etende                       0         1           0               0
# nagana                           0         1           1               0
#
#                          combined_long
# diplomet                             0
# nabu                                 0
# indresogen                           0
# kunstakademis                        0
# norden                               1
# clubstør                             0
# rash                                 0
# job                                  0
# hemstemvet                           0
# avturgåerne                          0
# katteunger                           0
# eiendoms-etaten                      1
# dyrekjør                             0
# misforståtd                          0
# kalia                                0
# høygtalereneee                       0
# retiner                              1
# bisadresser                          0
# ytuns-politikk                       0
# bøgd                                 3
# stillesert                           0
# sreiner                              0
# nåri                                 1
# forretnings-forbindelse              0
# forfatnings-domstolen                1
# diologien                            0
# takttk                               0
# tekstil-kunstnere                    1
# tou-treckingvvv                      0
# hmes                                 3
# oksid                                0
# gurku                                0
# kome                                 1
# sjebner                              2
# tennes-klubb                         0
# ukefordi                             0
# autumatkassen                        0
# plangåenden                          0
# gåren                                0
# ubarbeirt                            0
# oppmerksommen                        0
# fiv                                  2
# passasjerdøyntj                      0
# skarret                              1
# jass-musikken                        0
# staslig                              1
# atmosfæret                           0
# bordelb                              0
# matl                                 1
# malgarm                              0
# øyte                                 1
# eeeav                                0
# hangikk                              0
# ayithuns-politikk                    0
# deeltidsarbeidene                    0
# boyer                                0
# forsjelgere                          0
# milliard-beløp                       1
# brundsen                             0
# krayef                               0
# kjempe-artig                         1
# krangle                              0
# tsja                                 1
# turistaktraksjon                     1
# forståkete                           1
# jyda                                 1
# gaer                                 0
# dyrekjærr                            2
# marla                                0
# sekxs-lærere                         0
# studian                              0
# plutselg                             0
# bilee                                0
# diste                                0
# godtur                               0
# sommaertid                           0
# perlemorskyer                        1
# forelesinger                         1
# altsett                              0
# teby                                 1
# bortsendte                           1
# vanliga                              0
# januar-kullen                        0
# oawards                              0
# gjegotjeneste                        0
# marebakken                           1
# premiært                             0
# dannelses-begrepet                   1
# iatoy                                0
# fjok                                 0
# plagånn                              0
# stockmour                            3
# povepoynt                            0
# sykleren                             1
# pbortvin                             0
# slenge                               0
# tengninger                           0
# øren                                 2
# alt-etende                           0
# nagana                               0

# %%
hap_stortinget.query("reference == 0").sample(100, random_state=1)
# Out:
#                       reference  rundkast  stortinget  combined_short  \
# harmanisere                   0         1           1               1
# mongene                       0         0           1               0
#
#                       combined_long
# hurtigs                           0
# forbillelig                       1
# voyekleivene                      0
# ligene                            0
# molyjessen                        0
# meforskjellige                    0
# løvende                           0
# selvb                             0
# rekerasjonsområder                0
# oppretten                         0
# sengsrom                          1
# depresivt                         1
# ringt                             0
# rådhett                           0
# brønnesunn                        0
# skjeve                            0
# livh                              0
# toppyttelse                       2
# skyllerne                         0
# banevesenet                       0
# kjennertegnes                     0
# askelad                           0
# kirurgere                         1
# boke                              0
# fraperende                        1
# naturlige                         0
# vedunderlige                      0
# stiarynlys                        0
# ollerreit                         0
# stripbemerket                     0
# kunnstartere                      0
# toga                              1
# altid                             0
# snupa                             1
# utdeltttt                         0
# rinner                            0
# hunr                              0
# øllos                             0
# bermudasjårt                      1
# finna                             0
# kunstriske                        0
# valfangsten                       0
# hykeler                           0
# mannskapt                         0
# nedekk                            0
# svartmedalj                       0
# apel-produkter                    1
# ityns-politikk                    2
# stalene                           1
# sylig                             2
# venilie                           0
# jegt                              0
# ogve                              0
# oghun                             0
# papillommeterkler                 0
# scricing-                         0
# ranjene                           1
# moymm                             0
# finansiell                        0
# bora                              0
# vinnervillie                      0
# undeveis                          0
# pessen                            1
# trondhjeim                        0
# ukskriftstørrelsen                0
# blaudekonsonantene                0
# gjennomtengt                      0
# siko                              0
# barndomsveniname                  0
# åmarkerer                         0
# handleggestillinger               0
# listeo                            1
# studieseneddd                     0
# bran                              2
# klattere                          0
# tidaeiler                         0
# gradd                             0
# oljeprisk                         0
# cuto                              0
# falltid                           0
# jumnasium                         0
# kornelgrimen                      0
# kjøreen                           1
# enegbolig                         0
# flatmark                          1
# entertegner-reportar              0
# villmarksgaid                     0
# gudier                            0
# barefisk                          0
# ergvelser                         0
# bomringmm                         0
# apotekevarer                      1
# hjemmeforsikring                  0
# data-hverdag                      0
# trold                            14
# skjem                             3
# caus                              0
# sværre                            1
# harmanisere                       1
# mongene                           0

# %%
hap_combined_short.query("reference == 0").sample(100, random_state=1)
# Out:
#                         reference  rundkast  stortinget  combined_short  \
# festk                           0         0           0               1
# godd                            0         1           4               1
# benene                          0         0           1               1
# dawnport                        0         0           0               1
# oppover-bakker                  0         0           0               1
# leda                            0         0           0               1
# danse-forestillinger            0         1           0               1
# somnm                           0         0           0               1
# eierselskapet                   0         0           1               1
# suplement                       0         0           0               1
# seirtal                         0         0           0               1
# samlivnsår                      0         0           0               1
# domenikanerkirken               0         0           0               1
# ofta                            0         1           0               1
# basis-emne                      0         1           0               1
# fiskene                         0         2           2               1
# langrein                        0         1           1               1
# barnen                          0         2           1               1
# papir-kroven                    0         0           0               1
# kvinne-relatert                 0         1           0               1
# herrendig                       0         0           0               1
# aaturgåderne                    0         0           0               1
# entet                           0         0           0               1
# negseer                         0         0           0               1
# negels                          0         1           0               1
# genativ                         0         3           0               1
# havnarbeiderne                  0         1           1               1
# iypodd                          0         1           1               1
# haimgarden                      0         0           1               1
# vanskligere                     0         0           0               1
# fulles                          0         1           0               1
# drotnent                        0         1           0               1
# annomasjonsfilmer               0         0           1               1
# måkae                           0         0           0               1
# safranar                        0         1           1               1
# yokere                          0         0           0               1
# interrims-president             0         0           0               1
# likgjildig                      0         0           0               1
# mykjålaen                       0         1           0               1
# syvnde                          0         2           0               1
# scarsh                          0         0           0               1
# itiuns                          0         0           0               1
# sgernar-øyene                   0         0           0               1
# majaro                          0         0           1               1
# willa                           0         1           2               1
# lennord                         0         0           0               1
# infint                          0         0           0               1
# bommingen                       0         0           1               1
# påli                            0         0           0               1
# thorild                         0         0           1               1
# kick                            0         1           0               1
# trandsjoik                      0         1           0               1
# vinduekk                        0         0           0               1
# lærete                          0         0           1               1
# waarchl                         0         0           0               1
# foløu                           0         0           0               1
# badehånklær                     0         0           0               1
# downligds                       0         0           0               1
# byggen                          0         0           1               1
# øsby                            0         0           0               1
# gjøn                            0         0           1               1
# tvile                           0         1           0               1
# motive                          0         0           0               1
# kanadierne                      0         1           0               1
# koop                            0         0           2               1
# stiven                          0         1           1               1
# julnisten                       0         1           0               1
# blåberturene                    0         0           0               1
# sui                             0         0           0               1
# garlasjen                       0         0           0               1
# nordis                          0         1           0               1
# paraply-gran                    0         0           0               1
# hære                            0         0           0               1
# ytt                             0         0           1               1
# folkefordrystelse               0         1           1               1
# varet                           0         2           2               1
# bundn                           0         0           1               1
# tingt                           0         0           1               1
# heimstedsit                     0         0           1               1
# komite                          0         2           0               1
# køyre                           0         1           1               1
# vennigjengjennomføring          0         0           0               1
# esene                           0         1           1               1
# sidenl                          0         0           0               1
# utgifta                         0         0           0               1
# unige                           0         1           0               1
# ods                             0         2           4               1
# ruteskip                        0         0           0               1
# restaurant-bransjen             0         1           0               1
# dekatt                          0         0           0               1
# sjangeren                       0         1           1               1
# olad                            0         1           1               1
# desemberd                       0         0           1               1
# acid                            0         0           0               1
# egog                            0         0           0               1
# lærpums                         0         0           2               1
# kurytå                          0         0           0               1
# skulpe                          0         1           2               1
# særpreget                       0         0           1               1
# innenbo                         0         5           3               1
#
#                         combined_long
# festk                               0
# godd                                1
# benene                              0
# dawnport                            0
# oppover-bakker                      1
# leda                                1
# danse-forestillinger                1
# somnm                               0
# eierselskapet                       1
# suplement                           0
# seirtal                             0
# samlivnsår                          0
# domenikanerkirken                   0
# ofta                                1
# basis-emne                          0
# fiskene                             1
# langrein                            1
# barnen                              1
# papir-kroven                        0
# kvinne-relatert                     0
# herrendig                           0
# aaturgåderne                        0
# entet                               0
# negseer                             0
# negels                              0
# genativ                             0
# havnarbeiderne                      1
# iypodd                              0
# haimgarden                          1
# vanskligere                         0
# fulles                              0
# drotnent                            0
# annomasjonsfilmer                   0
# måkae                               0
# safranar                            0
# yokere                              0
# interrims-president                 1
# likgjildig                          0
# mykjålaen                           1
# syvnde                              0
# scarsh                              0
# itiuns                              1
# sgernar-øyene                       1
# majaro                              1
# willa                               0
# lennord                             0
# infint                              0
# bommingen                           1
# påli                                0
# thorild                             0
# kick                                1
# trandsjoik                          0
# vinduekk                            0
# lærete                              0
# waarchl                             0
# foløu                               0
# badehånklær                         0
# downligds                           0
# byggen                              0
# øsby                                0
# gjøn                                0
# tvile                               0
# motive                              0
# kanadierne                          1
# koop                                2
# stiven                              1
# julnisten                           0
# blåberturene                        0
# sui                                 0
# garlasjen                           0
# nordis                              0
# paraply-gran                        0
# hære                                0
# ytt                                 1
# folkefordrystelse                   1
# varet                               0
# bundn                               0
# tingt                               1
# heimstedsit                         0
# komite                              0
# køyre                               0
# vennigjengjennomføring              0
# esene                               1
# sidenl                              0
# utgifta                             0
# unige                               1
# ods                                 2
# ruteskip                            0
# restaurant-bransjen                 1
# dekatt                              0
# sjangeren                           1
# olad                                1
# desemberd                           0
# acid                                0
# egog                                0
# lærpums                             0
# kurytå                              0
# skulpe                              2
# særpreget                           1
# innenbo                             3

# %%
hap_combined_long.query("reference == 0").sample(100, random_state=1)
# Out:
#                           reference  rundkast  stortinget  combined_short  \
# ltså                              0         0           0               2
# øvne                              0         1           1               1
# lu                                0         1           1               1
# brukke                            0         0           0               0
# insitament                        0         1           1               1
# etvilsomt                         0         0           1               0
# utseden                           0         1           0               0
# aard                              0         0           0               0
# plagån                            0         0           0               0
# huse                              0         0           3               1
# kayjak-padling                    0         0           0               0
# iå                                0         0           0               0
# forløsnings-tanken                0         0           0               0
# speeagseth                        0         0           0               0
# searien                           0         0           0               0
# tryvs                             0         0           0               1
# treverken                         0         1           0               1
# ikt                               0         0           2               1
# ferida                            0         0           0               0
# donerings-knapp                   0         0           0               0
# seilfiskt                         0         0           0               0
# kokda                             0         1           1               0
# tromsdaen                         0         0           0               1
# våtekyss                          0         1           1               1
# buskju                            0         0           0               0
# stearynligs                       0         0           0               0
# lukdøra                           0         0           1               0
# hujer                             0         0           0               0
# fulene                            0         2           5               1
# ubunnhet                          0         1           0               0
# kausjonq                          0         0           0               0
# dugnads-ånnå                      0         0           0               0
# poplett                           0         0           0               0
# sandts                            0         0           0               0
# rekurasjons-område                0         0           0               3
# jerne                             0         0           1               0
# tyraniske                         0         1           1               0
# gjenomtrekk                       0         0           0               0
# rann-sona                         0         0           0               0
# ikskal                            0         0           0               0
# partis                            0         0           0               1
# mynn                              0         0           0               1
# stockmayr                         0         0           0               1
# målqq                             0         1           0               0
# jenemanns-tyver                   0         0           0               0
# notidsblokk                       0         1           3               2
# sjårt                             0         1           1               1
# lakker                            0         1           0               1
# gjørhom                           0         0           1               1
# sporti                            0         0           1               0
# flotser                           0         1           0               1
# plage-ånnen                       0         1           0               0
# baletten                          0         2           1               2
# opprinnerdig                      0         0           0               0
# bayiren                           0         0           0               0
# ryggmark-skader                   0         1           0               0
# harward                           0         0           0               0
# ubarbeit                          0         0           1               0
# foto-shompet                      0         0           0               0
# åee                               0         0           0               0
# studenter-sang-foreninga          0         1           0               0
# -løperen                          0         0           0               0
# gjennoppbygge                     0         1           1               0
# junatikk                          0         0           0               0
# blr                               0         0           1               0
# sist-nevnte                       0         0           0               1
# hje                               0         0           0               1
# sandvollyball                     0         0           0               0
